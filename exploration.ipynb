# %%
import cv2 as cv
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv(f'vinbigdata/train.csv')
train_df = train_df[train_df.class_id == 0]
train_df['image_path'] = f'vinbigdata/train/'+train_df.image_id+'.png'
train_df.head()
# Out:
#                             image_id          class_name  class_id rad_id  \
# 3   051132a778e61a86eb147c7c6f564dfe  Aortic enlargement         0    R10
# 8   d3637a1935a905b3c326af31389cb846  Aortic enlargement         0    R10
# 14  321c111713c3ee5385db0effb54ff568  Aortic enlargement         0     R8
# 18  5da264775732004f1b724b660138854a  Aortic enlargement         0     R9
# 19  fb8e11c6b2886b2d41b379e0598669b9  Aortic enlargement         0    R10
#
#      x_min  y_min   x_max   y_max  width  height  \
# 3   1264.0  743.0  1611.0  1019.0   2304    2880
# 8   1329.0  743.0  1521.0   958.0   2304    2880
# 14  1292.0  554.0  1477.0   805.0   2304    2880
# 18  1635.0  673.0  1978.0  1151.0   3072    3072
# 19  1390.0  878.0  1616.0  1163.0   2304    2880
#
#                                            image_path
# 3   vinbigdata/train/051132a778e61a86eb147c7c6f564...
# 8   vinbigdata/train/d3637a1935a905b3c326af31389cb...
# 14  vinbigdata/train/321c111713c3ee5385db0effb54ff...
# 18  vinbigdata/train/5da264775732004f1b724b6601388...
# 19  vinbigdata/train/fb8e11c6b2886b2d41b379e059866...

# %%
train_df['x_min'] = train_df.apply(lambda row: (row.x_min)/row.width, axis =1)
train_df['y_min'] = train_df.apply(lambda row: (row.y_min)/row.height, axis =1)

train_df['x_max'] = train_df.apply(lambda row: (row.x_max)/row.width, axis =1)
train_df['y_max'] = train_df.apply(lambda row: (row.y_max)/row.height, axis =1)

train_df['x_mid'] = train_df.apply(lambda row: (row.x_max+row.x_min)/2, axis =1)
train_df['y_mid'] = train_df.apply(lambda row: (row.y_max+row.y_min)/2, axis =1)

train_df['w'] = train_df.apply(lambda row: (row.x_max-row.x_min), axis =1)
train_df['h'] = train_df.apply(lambda row: (row.y_max-row.y_min), axis =1)

train_df['area'] = train_df['w']*train_df['h']
train_df.head()
# Out:
#                             image_id          class_name  class_id rad_id  \
# 3   051132a778e61a86eb147c7c6f564dfe  Aortic enlargement         0    R10
# 8   d3637a1935a905b3c326af31389cb846  Aortic enlargement         0    R10
# 14  321c111713c3ee5385db0effb54ff568  Aortic enlargement         0     R8
# 18  5da264775732004f1b724b660138854a  Aortic enlargement         0     R9
# 19  fb8e11c6b2886b2d41b379e0598669b9  Aortic enlargement         0    R10
#
#        x_min     y_min     x_max     y_max  width  height  \
# 3   0.548611  0.257986  0.699219  0.353819   2304    2880
# 8   0.576823  0.257986  0.660156  0.332639   2304    2880
# 14  0.560764  0.192361  0.641059  0.279514   2304    2880
# 18  0.532227  0.219076  0.643880  0.374674   3072    3072
# 19  0.603299  0.304861  0.701389  0.403819   2304    2880
#
#                                            image_path     x_mid     y_mid  \
# 3   vinbigdata/train/051132a778e61a86eb147c7c6f564...  0.623915  0.305903
# 8   vinbigdata/train/d3637a1935a905b3c326af31389cb...  0.618490  0.295312
# 14  vinbigdata/train/321c111713c3ee5385db0effb54ff...  0.600911  0.235938
# 18  vinbigdata/train/5da264775732004f1b724b6601388...  0.588053  0.296875
# 19  vinbigdata/train/fb8e11c6b2886b2d41b379e059866...  0.652344  0.354340
#
#            w         h      area
# 3   0.150608  0.095833  0.014433
# 8   0.083333  0.074653  0.006221
# 14  0.080295  0.087153  0.006998
# 18  0.111654  0.155599  0.017373
# 19  0.098090  0.098958  0.009707
